# %% [markdown]
# # Capstone Project: The Battles of Neighborhood - Final
# ### By Cristiane Foust
#
# # Opening an Upscale Brazilian Steakhouse in Toronto, CA
#
# ## 1. Introduction/Business Problem
#
# In this project, we will explore ideal neighborhood locations to open a Brazilian steakhouse restaurant.  This report will be used by stakeholders interested in opening an upscale all-you-can-eat Brazilian steakhouse restaurant in Toronto, Canada. Stakeholders already have 6 successful upscale all-you-can-eat Brazilian steakhouses in Brazil and 10 in United States. They decided to expand their business to Canada starting in Toronto since Toronto is the largest city with population more than 5.4 million. We will look for existing upscale restaurants in the vicinity of Toronto in each neighborhood and if there are any upscale Brazilian steakhouses. We will then focus our preliminary analysis to give the best possible neighborhood options for stakeholders in order to open an upscale all-you-can-eat Brazilian steakhouse restaurant in Toronto.

# %% [markdown]
# ## 2. Data
#
# In this project, we will use the following data sources:
#
# 1. Neighborhood data of Toronto City from the Wikipedia page https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M.
# (From this data, we will extract 'Postal code', 'Borough' and 'Neighborhood' for Toronto)
#
# 2. Download of location data using the link http://cocl.us/Geospatial_data to extract the ‘Latitude’ and ‘Longitude’ for Toronto neighborhoods.
#
# 3. Foursquare API to retrieve geo-location information for existing upscale restaurants in each neighborhood in Toronto and then verify if there are any upscale Brazilian steakhouses in Toronto.
#
# Finally we will analyze the above data sources to identify ideal neighborhood locations in Toronto to open a Brazilian steakhouse restaurant.We just need to be aware that this report relies on the accuracy of Foursquare API for Toronto, CA.

# %% [markdown]
# ### 2.1 Import Libraries

# %%
import pandas as pd
import numpy as np
import json
import requests
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
#Use geopy library to get the latitude and longitude values
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
# !pip install beautifulsoup4
from bs4 import BeautifulSoup
# !pip install html5lib
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.2 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0         conda-forge
#     geopy:         1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     openssl:       1.1.1c-h516909a_0 conda-forge --> 1.1.1d-h516909a_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting beautifulsoup4
#   Downloading https://files.pythonhosted.org/packages/3b/c8/a55eb6ea11cd7e5ac4bacdf92bac4693b90d3ba79268be16527555e186f0/beautifulsoup4-4.8.1-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 20.5MB/s ta 0:00:01
# Collecting soupsieve>=1.2 (from beautifulsoup4)
#   Downloading https://files.pythonhosted.org/packages/81/94/03c0f04471fc245d08d0a99f7946ac228ca98da4fa75796c507f61e688c2/soupsieve-1.9.5-py2.py3-none-any.whl
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.8.1 soupsieve-1.9.5
# Requirement already satisfied: html5lib in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.9999999)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from html5lib) (1.12.0)

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### 2.2 Transform neighborhood data of Toronto City from the Wikipedia page using the BeautifulSoup package into a pandas dataframe.

# %%
CA_website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %%
#import lxml
soup = BeautifulSoup(CA_website_url, "html5lib")
htmltable = soup.find('table', { 'class' : 'wikitable sortable' })

# %%
def tableDataText(table):       
    rows = []
    trs = table.find_all('tr')
    headerow = [td.get_text(strip=True) for td in trs[0].find_all('th')] # header row
    if headerow: # if there is a header row include first
        rows.append(headerow)
        trs = trs[1:]
    for tr in trs: # for every table row
        rows.append([td.get_text(strip=True) for td in tr.find_all('td')]) # data row
    return rows

# %%
list_table = tableDataText(htmltable)

# %%
import pandas as pd
dftable = pd.DataFrame(list_table[1:], columns=list_table[0])
dftable.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights
# 7      M6A        North York    Lawrence Manor
# 8      M7A      Queen's Park      Not assigned
# 9      M8A      Not assigned      Not assigned

# %%
indexNames = dftable[ dftable['Borough'] =='Not assigned'].index

dftable.drop(indexNames , inplace=True)

# %%
dftable.loc[dftable['Neighbourhood'] =='Not assigned' , 'Neighbourhood'] = dftable['Borough']

# %%
result = dftable.groupby(['Postcode','Borough'], sort=False).agg( ', '.join)
df_new=result.reset_index()
df_new.head(15)
# Out:
#    Postcode           Borough  \
# 0       M3A        North York
# 1       M4A        North York
# 2       M5A  Downtown Toronto
# 3       M6A        North York
# 4       M7A      Queen's Park
# 5       M9A         Etobicoke
# 6       M1B       Scarborough
# 7       M3B        North York
# 8       M4B         East York
# 9       M5B  Downtown Toronto
# 10      M6B        North York
# 11      M9B         Etobicoke
# 12      M1C       Scarborough
# 13      M3C        North York
# 14      M4C         East York
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                           Harbourfront, Regent Park
# 3                    Lawrence Heights, Lawrence Manor
# 4                                        Queen's Park
# 5                                    Islington Avenue
# 6                                      Rouge, Malvern
# 7                                     Don Mills North
# 8                     Woodbine Gardens, Parkview Hill
# 9                            Ryerson, Garden District
# 10                                          Glencairn
# 11  Cloverdale, Islington, Martin Grove, Princess ...
# 12             Highland Creek, Rouge Hill, Port Union
# 13                   Flemingdon Park, Don Mills South
# 14                                   Woodbine Heights

# %%
df_new.shape
# Out:
# (103, 3)

# %% [markdown]
# ### 2.3 Use Toronto location data csv file to create a dataframe with latitude and longitude values

# %%
# !wget -q -O 'Toronto_long_lat_data.csv'  http://cocl.us/Geospatial_data
df_long_lat = pd.read_csv('Toronto_long_lat_data.csv')
df_long_lat.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_long_lat.columns=['Postalcode','Latitude','Longitude']
df_long_lat.head()
# Out:
#   Postalcode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %%
df_pc_long_lat = df_long_lat.rename(columns={'Postalcode':'Postcode'})
df_pc_long_lat.set_index("Postcode")
df_new.set_index("Postcode")
toronto_data=pd.merge(df_new, df_pc_long_lat)
toronto_data
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# 30       M5H  Downtown Toronto
# 31       M6H      West Toronto
# 32       M1J       Scarborough
# 33       M2J        North York
# 34       M3J        North York
# 35       M4J         East York
# 36       M5J  Downtown Toronto
# 37       M6J      West Toronto
# 38       M1K       Scarborough
# 39       M2K        North York
# 40       M3K        North York
# 41       M4K      East Toronto
# 42       M5K  Downtown Toronto
# 43       M6K      West Toronto
# 44       M1L       Scarborough
# 45       M2L        North York
# 46       M3L        North York
# 47       M4L      East Toronto
# 48       M5L  Downtown Toronto
# 49       M6L        North York
# 50       M9L        North York
# 51       M1M       Scarborough
# 52       M2M        North York
# 53       M3M        North York
# 54       M4M      East Toronto
# 55       M5M        North York
# 56       M6M              York
# 57       M9M        North York
# 58       M1N       Scarborough
# 59       M2N        North York
# 60       M3N        North York
# 61       M4N   Central Toronto
# 62       M5N   Central Toronto
# 63       M6N              York
# 64       M9N              York
# 65       M1P       Scarborough
# 66       M2P        North York
# 67       M4P   Central Toronto
# 68       M5P   Central Toronto
# 69       M6P      West Toronto
# 70       M9P         Etobicoke
# 71       M1R       Scarborough
# 72       M2R        North York
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                         Queen's Park  43.662301 -79.389494
# 5                                     Islington Avenue  43.667856 -79.532242
# 6                                       Rouge, Malvern  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                      Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 12              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# 30                            Adelaide, King, Richmond  43.650571 -79.384568
# 31                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 32                                 Scarborough Village  43.744734 -79.239476
# 33                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 34                     Northwood Park, York University  43.767980 -79.487262
# 35                                        East Toronto  43.685347 -79.338106
# 36   Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 37                            Little Portugal, Trinity  43.647927 -79.419750
# 38         East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 39                                     Bayview Village  43.786947 -79.385975
# 40                         CFB Toronto, Downsview East  43.737473 -79.464763
# 41                        The Danforth West, Riverdale  43.679557 -79.352188
# 42            Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 43        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 44                     Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 45                            Silver Hills, York Mills  43.757490 -79.374714
# 46                                      Downsview West  43.739015 -79.506944
# 47                      The Beaches West, India Bazaar  43.668999 -79.315572
# 48                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 49                  Downsview, North Park, Upwood Park  43.713756 -79.490074
# 50                                       Humber Summit  43.756303 -79.565963
# 51     Cliffcrest, Cliffside, Scarborough Village West  43.716316 -79.239476
# 52                             Newtonbrook, Willowdale  43.789053 -79.408493
# 53                                   Downsview Central  43.728496 -79.495697
# 54                                     Studio District  43.659526 -79.340923
# 55                   Bedford Park, Lawrence Manor East  43.733283 -79.419750
# 56      Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.691116 -79.476013
# 57                                    Emery, Humberlea  43.724766 -79.532242
# 58                         Birch Cliff, Cliffside West  43.692657 -79.264848
# 59                                    Willowdale South  43.770120 -79.408493
# 60                                 Downsview Northwest  43.761631 -79.520999
# 61                                       Lawrence Park  43.728020 -79.388790
# 62                                            Roselawn  43.711695 -79.416936
# 63                       The Junction North, Runnymede  43.673185 -79.487262
# 64                                              Weston  43.706876 -79.518188
# 65   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 66                                     York Mills West  43.752758 -79.400049
# 67                                    Davisville North  43.712751 -79.390197
# 68                 Forest Hill North, Forest Hill West  43.696948 -79.411307
# 69                       High Park, The Junction South  43.661608 -79.464763
# 70                                           Westmount  43.696319 -79.532242
# 71                                   Maryvale, Wexford  43.750072 -79.295849
# 72                                     Willowdale West  43.782736 -79.442259
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      Harbord, University of Toronto  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 85   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 90                                     L'Amoreaux West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 101  Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 102  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999

# %% [markdown]
# ### 2.4 Get geographical coordinates of Toronto

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="Toronto")
location = geolocator.geocode(address)
latitude_toronto = location.latitude
longitude_toronto = location.longitude
print('The geographical coordinates of Toronto are {}, {}.'.format(latitude_toronto, longitude_toronto))
# Out:
# The geographical coordinates of Toronto are 43.653963, -79.387207.

# %% [markdown]
# ### 2.5 Use Foursquare API to retrieve geo-location information from all upscale restaurants in each neighborhood in Toronto

# %%
CLIENT_ID = 'MHSM3SCFN51MFFPY0IWYRVORS0WWLMONRIEGDU2YYCRDGDX3' # your Foursquare ID
CLIENT_SECRET = 'DJA15GQSOHK3TRZZT0XP1X4U5FEI5BJZRLH2HQWNZNRAE1Z1' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: MHSM3SCFN51MFFPY0IWYRVORS0WWLMONRIEGDU2YYCRDGDX3
# CLIENT_SECRET:DJA15GQSOHK3TRZZT0XP1X4U5FEI5BJZRLH2HQWNZNRAE1Z1

# %%
# defining radius and limit of venues to get
radius=500
LIMIT=100

# %%
import json # library to handle JSON files
def getUpscaleRestaurantVenues(names, latitudes, longitudes, borough, radius=500):
    
    venues_list=[]
    for name, lat, lng, borough in zip(names, latitudes, longitudes, borough):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&section=food&price=4'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng,
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            borough,
            v['venue']['name'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_food_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_food_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Borough', 
                  'Venue', 
                  'Venue Category']
    
    return(nearby_food_venues)

# %%
toronto_venues = getUpscaleRestaurantVenues(names=toronto_data['Neighbourhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude'],
                                            borough=toronto_data['Borough']
                                  )

# %%
toronto_venues
# Out:
#                                         Neighbourhood  Neighbourhood Latitude  \
# 0                           Harbourfront, Regent Park               43.654260
# 1                           Harbourfront, Regent Park               43.654260
# 2                                     Don Mills North               43.745906
# 3                            Ryerson, Garden District               43.657162
# 4                                      St. James Town               43.651494
# 5                                      St. James Town               43.651494
# 6                                      St. James Town               43.651494
# 7                                         Berczy Park               43.644771
# 8                                             Leaside               43.709060
# 9                                  Central Bay Street               43.657952
# 10                           Adelaide, King, Richmond               43.650571
# 11                           Adelaide, King, Richmond               43.650571
# 12                           Adelaide, King, Richmond               43.650571
# 13                           Adelaide, King, Richmond               43.650571
# 14                           Adelaide, King, Richmond               43.650571
# 15                           Adelaide, King, Richmond               43.650571
# 16                           Adelaide, King, Richmond               43.650571
# 17                           Adelaide, King, Richmond               43.650571
# 18                           Adelaide, King, Richmond               43.650571
# 19  Harbourfront East, Toronto Islands, Union Station               43.640816
# 20  Harbourfront East, Toronto Islands, Union Station               43.640816
# 21  Harbourfront East, Toronto Islands, Union Station               43.640816
# 22                           Little Portugal, Trinity               43.647927
# 23           Design Exchange, Toronto Dominion Centre               43.647177
# 24           Design Exchange, Toronto Dominion Centre               43.647177
# 25           Design Exchange, Toronto Dominion Centre               43.647177
# 26           Design Exchange, Toronto Dominion Centre               43.647177
# 27           Design Exchange, Toronto Dominion Centre               43.647177
# 28           Design Exchange, Toronto Dominion Centre               43.647177
# 29           Design Exchange, Toronto Dominion Centre               43.647177
# 30           Design Exchange, Toronto Dominion Centre               43.647177
# 31           Design Exchange, Toronto Dominion Centre               43.647177
# 32           Design Exchange, Toronto Dominion Centre               43.647177
# 33                     Commerce Court, Victoria Hotel               43.648198
# 34                     Commerce Court, Victoria Hotel               43.648198
# 35                     Commerce Court, Victoria Hotel               43.648198
# 36                     Commerce Court, Victoria Hotel               43.648198
# 37                     Commerce Court, Victoria Hotel               43.648198
# 38                     Commerce Court, Victoria Hotel               43.648198
# 39                     Commerce Court, Victoria Hotel               43.648198
# 40                     Commerce Court, Victoria Hotel               43.648198
# 41                     Commerce Court, Victoria Hotel               43.648198
# 42                                    Studio District               43.659526
# 43                  Bedford Park, Lawrence Manor East               43.733283
# 44                  Bedford Park, Lawrence Manor East               43.733283
# 45                                   Willowdale South               43.770120
# 46                                   Willowdale South               43.770120
# 47                      High Park, The Junction South               43.661608
# 48                    Stn A PO Boxes 25 The Esplanade               43.646435
# 49                    Stn A PO Boxes 25 The Esplanade               43.646435
# 50                    Stn A PO Boxes 25 The Esplanade               43.646435
# 51             First Canadian Place, Underground city               43.648429
# 52             First Canadian Place, Underground city               43.648429
# 53             First Canadian Place, Underground city               43.648429
# 54             First Canadian Place, Underground city               43.648429
# 55             First Canadian Place, Underground city               43.648429
# 56             First Canadian Place, Underground city               43.648429
# 57             First Canadian Place, Underground city               43.648429
# 58             First Canadian Place, Underground city               43.648429
# 59             First Canadian Place, Underground city               43.648429
# 60             First Canadian Place, Underground city               43.648429
# 61                               Church and Wellesley               43.665860
#
#     Neighbourhood Longitude           Borough  \
# 0                -79.360636  Downtown Toronto
# 1                -79.360636  Downtown Toronto
# 2                -79.352188        North York
# 3                -79.378937  Downtown Toronto
# 4                -79.375418  Downtown Toronto
# 5                -79.375418  Downtown Toronto
# 6                -79.375418  Downtown Toronto
# 7                -79.373306  Downtown Toronto
# 8                -79.363452         East York
# 9                -79.387383  Downtown Toronto
# 10               -79.384568  Downtown Toronto
# 11               -79.384568  Downtown Toronto
# 12               -79.384568  Downtown Toronto
# 13               -79.384568  Downtown Toronto
# 14               -79.384568  Downtown Toronto
# 15               -79.384568  Downtown Toronto
# 16               -79.384568  Downtown Toronto
# 17               -79.384568  Downtown Toronto
# 18               -79.384568  Downtown Toronto
# 19               -79.381752  Downtown Toronto
# 20               -79.381752  Downtown Toronto
# 21               -79.381752  Downtown Toronto
# 22               -79.419750      West Toronto
# 23               -79.381576  Downtown Toronto
# 24               -79.381576  Downtown Toronto
# 25               -79.381576  Downtown Toronto
# 26               -79.381576  Downtown Toronto
# 27               -79.381576  Downtown Toronto
# 28               -79.381576  Downtown Toronto
# 29               -79.381576  Downtown Toronto
# 30               -79.381576  Downtown Toronto
# 31               -79.381576  Downtown Toronto
# 32               -79.381576  Downtown Toronto
# 33               -79.379817  Downtown Toronto
# 34               -79.379817  Downtown Toronto
# 35               -79.379817  Downtown Toronto
# 36               -79.379817  Downtown Toronto
# 37               -79.379817  Downtown Toronto
# 38               -79.379817  Downtown Toronto
# 39               -79.379817  Downtown Toronto
# 40               -79.379817  Downtown Toronto
# 41               -79.379817  Downtown Toronto
# 42               -79.340923      East Toronto
# 43               -79.419750        North York
# 44               -79.419750        North York
# 45               -79.408493        North York
# 46               -79.408493        North York
# 47               -79.464763      West Toronto
# 48               -79.374846  Downtown Toronto
# 49               -79.374846  Downtown Toronto
# 50               -79.374846  Downtown Toronto
# 51               -79.382280  Downtown Toronto
# 52               -79.382280  Downtown Toronto
# 53               -79.382280  Downtown Toronto
# 54               -79.382280  Downtown Toronto
# 55               -79.382280  Downtown Toronto
# 56               -79.382280  Downtown Toronto
# 57               -79.382280  Downtown Toronto
# 58               -79.382280  Downtown Toronto
# 59               -79.382280  Downtown Toronto
# 60               -79.382280  Downtown Toronto
# 61               -79.383160  Downtown Toronto
#
#                                  Venue              Venue Category
# 0           Cluny Bistro & Boulangerie           French Restaurant
# 1    Pure Spirits Oyster House & Grill          Seafood Restaurant
# 2                          Gonoe Sushi         Japanese Restaurant
# 3              Barberian's Steak House                  Steakhouse
# 4                    GEORGE Restaurant                  Restaurant
# 5                              Carisma          Italian Restaurant
# 6     Wildfire Steakhouse Cosmopolitan                  Steakhouse
# 7                   Harbour 60 Toronto                  Steakhouse
# 8                            GRILLTIME                  Steakhouse
# 9              Barberian's Steak House                  Steakhouse
# 10                  Bosk at Shangri-La            Asian Restaurant
# 11                    Estiatorio Volos            Greek Restaurant
# 12                     Hy's Steakhouse                  Steakhouse
# 13                               Kojin        Colombian Restaurant
# 14                 Michael's on Simcoe                  Steakhouse
# 15                           Nota Bene         American Restaurant
# 16                              Bymark                  Restaurant
# 17                 The Fifth & Terrace  Modern European Restaurant
# 18                        Los Colibris          Mexican Restaurant
# 19                  Harbour 60 Toronto                  Steakhouse
# 20                     Aria Ristorante          Italian Restaurant
# 21              Streak's Bar and Grill                  Steakhouse
# 22                             Böehmer     New American Restaurant
# 23                              Bymark                  Restaurant
# 24                     Hy's Steakhouse                  Steakhouse
# 25                  Bosk at Shangri-La            Asian Restaurant
# 26                    Estiatorio Volos            Greek Restaurant
# 27                                TOCA          Italian Restaurant
# 28                 Michael's on Simcoe                  Steakhouse
# 29                               Kojin        Colombian Restaurant
# 30                    Little Anthony's          Italian Restaurant
# 31    Wildfire Steakhouse Cosmopolitan                  Steakhouse
# 32                  LA's Italian + Bar          Italian Restaurant
# 33                              Bymark                  Restaurant
# 34                     Hy's Steakhouse                  Steakhouse
# 35                             Carisma          Italian Restaurant
# 36                    Estiatorio Volos            Greek Restaurant
# 37                  Bosk at Shangri-La            Asian Restaurant
# 38                    Little Anthony's          Italian Restaurant
# 39                               BATCH                   Gastropub
# 40    Wildfire Steakhouse Cosmopolitan                  Steakhouse
# 41                  LA's Italian + Bar          Italian Restaurant
# 42                               M’Eat                  Steakhouse
# 43                         Francobollo          Italian Restaurant
# 44                          Nara Sushi         Japanese Restaurant
# 45                             The Keg                  Steakhouse
# 46  Symposium Cafe Restaurant & Lounge                  Restaurant
# 47                              Aquila                  Steakhouse
# 48                             Carisma          Italian Restaurant
# 49    Wildfire Steakhouse Cosmopolitan                  Steakhouse
# 50                   Biagio Ristorante          Italian Restaurant
# 51                              Bymark                  Restaurant
# 52                     Hy's Steakhouse                  Steakhouse
# 53                  Bosk at Shangri-La            Asian Restaurant
# 54                    Estiatorio Volos            Greek Restaurant
# 55                 Michael's on Simcoe                  Steakhouse
# 56                               Kojin        Colombian Restaurant
# 57                    Little Anthony's          Italian Restaurant
# 58                        Los Colibris          Mexican Restaurant
# 59    Wildfire Steakhouse Cosmopolitan                  Steakhouse
# 60                  LA's Italian + Bar          Italian Restaurant
# 61                      Loaded Pierogi           Polish Restaurant

# %% [markdown]
# ## 3. Methodology
#
# This is the most important component of the report. This is where we discuss and explain any exploratory data analysis completed, any inferential statistical testing performed, and what kind of machine learning technique was used and why. From the above data, we used content-based recommendation technique to solve the problem.
#
# After analyzing the Foursquare API data, we noticed that there aren't any upscale all-you-can-eat Brazilian steakhouse restaurants (Brazilian Churrascarias) in Toronto. This means that stakeholders would not have a direct competition if they open their new restaurant in any of the neighborhoods in Toronto. Since stakeholders mentioned that their other restaurants are very popular with businesses and, at the same time, they are very family-friendly, it is essential for them to be close to other popular upscale restaurants. A Brazilian steakhouse is not exactly the same as other steakhouses. This type of steakhouse is called "rodizio" which means that many Brazilian cowboys ("gaúchos") walk table to table with different cuts of meat, chicken, sausages and even seafood. There are always a very large salad bar at the center of the restaurant. We also noticed that most of the upscale restaurants are located in the Borough of Toronto Downtown.
#
# Let's now plot all upscale restaurant locations from above into a folium map to see their exact locations (in red) and then  compare them with each neighborhood (in blue).

# %%
map_toronto = folium.Map(location=[latitude_toronto, longitude_toronto], zoom_start=10)

# add neighborhood markers to map
for lat, lng, borough, Neighbourhood in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Borough'], toronto_data['Neighbourhood']):
    label = '{}, {}'.format(Neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
# add upscale restaurant markers to map
for lat, lng, Neighbourhood in zip(toronto_venues['Neighbourhood Latitude'], toronto_venues['Neighbourhood Longitude'], toronto_venues['Neighbourhood']):
    label = '{}'.format(Neighbourhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=1,
        popup=label,
        color='red',
        fill=False,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3.1 Let's find how many upscale restaurants are there per neighborhood.

# %%
toronto_venues['Neighbourhood'].value_counts().to_frame(name='Count')
# Out:
#                                                    Count
# First Canadian Place, Underground city                10
# Design Exchange, Toronto Dominion Centre              10
# Adelaide, King, Richmond                               9
# Commerce Court, Victoria Hotel                         9
# St. James Town                                         3
# Harbourfront East, Toronto Islands, Union Station      3
# Stn A PO Boxes 25 The Esplanade                        3
# Bedford Park, Lawrence Manor East                      2
# Harbourfront, Regent Park                              2
# Willowdale South                                       2
# Little Portugal, Trinity                               1
# Berczy Park                                            1
# Ryerson, Garden District                               1
# Don Mills North                                        1
# Leaside                                                1
# High Park, The Junction South                          1
# Church and Wellesley                                   1
# Studio District                                        1
# Central Bay Street                                     1

# %% [markdown]
# ## 4. Discussion
#
# The top 4 neighborhoods from the list above that have the highest number of upscale restaurants per postal code are all located in Downtown Toronto:
# 1. Design Exchange, Toronto Dominion Centre (M5K): 11 upscale restaurants
# 2. First Canadian Place, Underground city (M5X): 10 upscale restaurants
# 3. Commerce Court, Victoria Hotel (M5L): 10 upscale restaurants
# 4. Adelaide, King, Richmond (M5H): 9 upscale restaurants
#
# A new upscale Brazilian restaurant could be opened at any of these neighborhoods.

# %% [markdown]
# ## 5. Results
# Stakeholders were able to find 4 (four) best neighborhood locations per postal code for them to open their new Brazilian restaurant in Toronto Downtown.
# Further analysis to gather profitability, popularity and property prices for these areas should take place to create a weighting matrix. After this matrix is developed, we could select an optimal location for a new upscale Brazilian steakhouse in Toronto Downtown.
#
#
# ## 6. Conclusion
# Finally, we have used Python libraries to handle JSON files, plotted graph, and other exploratory data analysis. We used Foursquare API to explore all upscale restaurants in Toronto, Canada. We used content-based recommendation technique to solve the problem. We were able to find 4 (four) best neighborhood locations per postal code for stakeholders to open their new Brazilian restaurant in Toronto Downtown. However we found that they still need further analysis to gather profitability, popularity and property prices for each neighborhood by creating a weighting matrix. With this, they could find one ideal location for their new upscale all-you-can-eat Brazilian steakhouse in Toronto Downtown.
